# %%
print("METODE NUMERIK-01")
print("TUGAS 7 ORDINARY DIFFERENTIAL EQUATION")
print("CASE : FLUID MECHANICS PROBLEM")
print("Nama      : MUHAMMAD HURRICANE")
print("NPM       : 1906356191")

import matplotlib.pyplot as plt
import numpy as np
import math
#%matplotlib inline
a = int(input("Waktu t1 (s): "))
#Batas atas fungsi
b = int(input("Waktu t2 (s): "))
#Banyak segmen dan interval
seg = int(input('Banyak segmen : '))

x = np.linspace(a,b,seg)
def f(x):
    q = 4.8
    return -0.004783950617283948*x**2 + 0.1638888888888889*x + math.sin(q)
    #return -153.8461*2.7182818284590452353602874713527**(-0.273*x) - 563.539*2.7182818284590452353602874713527(-0.273*x) + ((5*math.sin(2*3.1415926535 8979323846*x))/3.1415926535 8979323846)
plt.plot(x,f(x))
plt.show

# =================================================================================
# Out:
# METODE NUMERIK-01
# TUGAS 7 ORDINARY DIFFERENTIAL EQUATION
# CASE : FLUID MECHANICS PROBLEM
# Nama      : MUHAMMAD HURRICANE
# NPM       : 1906356191
# <function matplotlib.pyplot.show(close=None, block=None)>
